# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("fragile_state_index.xlsx", header=[0])
#pd.read_excel("/tmp/sample.xlsx", usecols = "B:F", skiprows=[0])

# %%
    dictionary = {"key1": "value1"}
print(dictionary["key1"])
# Out:
# value1

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.dtypes)
# Out:
# Unnamed: 0                                   int64
# Country                                     object
# Year                                datetime64[ns]
# Rank                                        object
# Total                                      float64
# C1: Security Apparatus                     float64
# C2: Factionalized Elites                   float64
# C3: Group Grievance                        float64
# E1: Economy                                float64
# E2: Economic Inequality                    float64
# E3: Human Flight and Brain Drain           float64
# P1: State Legitimacy                       float64
# P2: Public Services                        float64
# P3: Human Rights                           float64
# S1: Demographic Pressures                  float64
# S2: Refugees and IDPs                      float64
# X1: External Intervention                  float64
# Change from Previous Year                  float64
# dtype: object

# %%
df
# Out:
#       Unnamed: 0                    Country       Year   Rank       Total  \
# 0              0                      Sudan 2006-01-01    1st  112.300000
# 1              1  Congo Democratic Republic 2006-01-01    2nd  110.100000
# 2              2              Cote d'Ivoire 2006-01-01    3rd  109.200000
# 3              3                       Iraq 2006-01-01    4th  109.000000
# 4              4                   Zimbabwe 2006-01-01    5th  108.900000
# ...          ...                        ...        ...    ...         ...
# 2628        2628                    Iceland 2020-01-01  174th   17.800000
# 2629        2629                    Denmark 2020-01-01  175th   17.213587
# 2630        2630                Switzerland 2020-01-01  176th   17.094086
# 2631        2631                     Norway 2020-01-01  177th   16.191210
# 2632        2632                    Finland 2020-01-01  178th   14.626666
#
#       C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                        9.8                       9.1                  9.7
# 1                        9.8                       9.6                  9.1
# 2                        9.8                       9.8                  9.8
# 3                        9.8                       9.7                  9.8
# 4                        9.4                       8.5                  8.5
# ...                      ...                       ...                  ...
# 2628                     1.0                       1.8                  0.7
# 2629                     1.6                       1.4                  4.0
# 2630                     1.4                       1.0                  3.0
# 2631                     1.8                       1.1                  3.6
# 2632                     2.8                       1.4                  0.9
#
#       E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0         7.50000                      9.2                               9.1
# 1         8.10000                      9.0                               8.0
# 2         9.00000                      8.0                               8.5
# 3         8.20000                      8.7                               9.1
# 4         9.80000                      9.2                               9.0
# ...           ...                      ...                               ...
# 2628      2.80000                      1.0                               2.2
# 2629      1.30000                      0.9                               1.6
# 2630      1.60000                      1.5                               1.4
# 2631      1.69121                      0.7                               1.0
# 2632      2.60000                      0.5                               1.7
#
#       P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                      9.5             9.500000               9.8
# 1                      9.0             9.000000               9.5
# 2                     10.0             8.500000               9.4
# 3                      8.5             8.300000               9.7
# 4                      8.9             9.500000               9.5
# ...                    ...                  ...               ...
# 2628                   0.7             0.700000               0.7
# 2629                   0.6             0.913587               1.4
# 2630                   0.5             1.052499               1.1
# 2631                   0.5             1.100000               0.6
# 2632                   0.6             0.626666               0.5
#
#       S1: Demographic Pressures  S2: Refugees and IDPs  \
# 0                      9.600000                    9.7
# 1                      9.500000                    9.5
# 2                      8.800000                    7.6
# 3                      8.900000                    8.3
# 4                      9.700000                    8.9
# ...                         ...                    ...
# 2628                   1.000000                    1.7
# 2629                   1.300000                    1.7
# 2630                   1.241587                    2.8
# 2631                   0.900000                    2.5
# 2632                   0.700000                    1.6
#
#       X1: External Intervention  Change from Previous Year
# 0                           9.8                        NaN
# 1                          10.0                        NaN
# 2                          10.0                        NaN
# 3                          10.0                        NaN
# 4                           8.0                        NaN
# ...                         ...                        ...
# 2628                        3.5                  -2.000000
# 2629                        0.5                  -2.286413
# 2630                        0.5                  -1.605914
# 2631                        0.7                  -1.808790
# 2632                        0.7                  -2.273334
#
# [2633 rows x 18 columns]

# %%
# Create dummy variables for the category_columns and merge on the numeric_columns to create an X dataset
# Define target data
# Create category_columns and numeric_columns variables
X = df.drop(['Country', 'Rank','Year','Total', 'C2: Factionalized Elites'], axis=1)
X
# Out:
#       Unnamed: 0  C1: Security Apparatus  C3: Group Grievance  E1: Economy  \
# 0              0                     9.8                  9.7      7.50000
# 1              1                     9.8                  9.1      8.10000
# 2              2                     9.8                  9.8      9.00000
# 3              3                     9.8                  9.8      8.20000
# 4              4                     9.4                  8.5      9.80000
# ...          ...                     ...                  ...          ...
# 2628        2628                     1.0                  0.7      2.80000
# 2629        2629                     1.6                  4.0      1.30000
# 2630        2630                     1.4                  3.0      1.60000
# 2631        2631                     1.8                  3.6      1.69121
# 2632        2632                     2.8                  0.9      2.60000
#
#       E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0                         9.2                               9.1
# 1                         9.0                               8.0
# 2                         8.0                               8.5
# 3                         8.7                               9.1
# 4                         9.2                               9.0
# ...                       ...                               ...
# 2628                      1.0                               2.2
# 2629                      0.9                               1.6
# 2630                      1.5                               1.4
# 2631                      0.7                               1.0
# 2632                      0.5                               1.7
#
#       P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                      9.5             9.500000               9.8
# 1                      9.0             9.000000               9.5
# 2                     10.0             8.500000               9.4
# 3                      8.5             8.300000               9.7
# 4                      8.9             9.500000               9.5
# ...                    ...                  ...               ...
# 2628                   0.7             0.700000               0.7
# 2629                   0.6             0.913587               1.4
# 2630                   0.5             1.052499               1.1
# 2631                   0.5             1.100000               0.6
# 2632                   0.6             0.626666               0.5
#
#       S1: Demographic Pressures  S2: Refugees and IDPs  \
# 0                      9.600000                    9.7
# 1                      9.500000                    9.5
# 2                      8.800000                    7.6
# 3                      8.900000                    8.3
# 4                      9.700000                    8.9
# ...                         ...                    ...
# 2628                   1.000000                    1.7
# 2629                   1.300000                    1.7
# 2630                   1.241587                    2.8
# 2631                   0.900000                    2.5
# 2632                   0.700000                    1.6
#
#       X1: External Intervention  Change from Previous Year
# 0                           9.8                        NaN
# 1                          10.0                        NaN
# 2                          10.0                        NaN
# 3                          10.0                        NaN
# 4                           8.0                        NaN
# ...                         ...                        ...
# 2628                        3.5                  -2.000000
# 2629                        0.5                  -2.286413
# 2630                        0.5                  -1.605914
# 2631                        0.7                  -1.808790
# 2632                        0.7                  -2.273334
#
# [2633 rows x 13 columns]

# %%
# Fill in missing values in X with zeroes
X = X.fillna(0)
y = df['P3: Human Rights']

# %%
pd.set_option('display.max_columns', 500)

# %%
X.apply(lambda s: pd.to_numeric(s, errors='coerce').notnull().all())
# Out:
# Unnamed: 0                          True
# C1: Security Apparatus              True
# C3: Group Grievance                 True
# E1: Economy                         True
# E2: Economic Inequality             True
# E3: Human Flight and Brain Drain    True
# P1: State Legitimacy                True
# P2: Public Services                 True
# P3: Human Rights                    True
# S1: Demographic Pressures           True
# S2: Refugees and IDPs               True
# X1: External Intervention           True
# Change from Previous Year           True
# dtype: bool

# %%
X.dtypes
# Out:
# Unnamed: 0                            int64
# C1: Security Apparatus              float64
# C3: Group Grievance                 float64
# E1: Economy                         float64
# E2: Economic Inequality             float64
# E3: Human Flight and Brain Drain    float64
# P1: State Legitimacy                float64
# P2: Public Services                 float64
# P3: Human Rights                    float64
# S1: Demographic Pressures           float64
# S2: Refugees and IDPs               float64
# X1: External Intervention           float64
# Change from Previous Year           float64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=60)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train.head()
# Out:
#       Unnamed: 0  C1: Security Apparatus  C3: Group Grievance  E1: Economy  \
# 2217        2217                     4.9                  3.7     4.008167
# 718          718                     5.0                  8.5     7.000000
# 2143        2143                     8.5                  4.2     6.600000
# 2271        2271                     2.4                  1.1     3.100000
# 2537        2537                     5.0                  4.2     7.900000
#
#       E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 2217                   5.1000                          4.900000
# 718                    7.2000                          7.000000
# 2143                   7.9000                          7.475282
# 2271                   1.9000                          2.565197
# 2537                   5.7035                          8.200000
#
#       P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 2217               7.58215             4.400000          7.200000
# 718                7.50000             7.400000          7.500000
# 2143               6.80000             8.400000          5.948356
# 2271               0.70000             1.441696          1.700000
# 2537               4.70000             5.600000          2.956628
#
#       S1: Demographic Pressures  S2: Refugees and IDPs  \
# 2217                   5.600000                    3.7
# 718                    9.100000                    7.0
# 2143                   8.800000                    6.3
# 2271                   1.532412                    1.7
# 2537                   6.393654                    5.1
#
#       X1: External Intervention  Change from Previous Year
# 2217                   4.800000                     0.0000
# 718                    7.500000                     0.0000
# 2143                   7.800000                     0.0000
# 2271                   1.100000                     0.0000
# 2537                   8.228119                    -0.8181

# %%
nn_model = tf.keras.models.Sequential()

# %%
nn_model.add(tf.keras.layers.Dense(units=len(X.columns) * 2, activation = "relu", input_dim = len(X.columns)))

# %%
nn_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
nn_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 26)                364
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 27
# =================================================================
# Total params: 391
# Trainable params: 391
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model.compile(loss="mean_squared_error", optimizer="adam")

# %%
nn_model.fit(X_train_scaled, np.asarray(y_train), epochs=100)
# Out:
# Epoch 1/100
# 62/62 [==============================] -
# 62/62 [==============================] - 0s 466us/step - loss: 1.8806e-04
# Epoch 79/100
# 62/62 [==============================] - 0s 483us/step - loss: 1.7062e-04
# Epoch 80/100
# 62/62 [==============================] - 0s 483us/step - loss: 1.5519e-04
# Epoch 81/100
# 62/62 [==============================] - 0s 467us/step - loss: 1.4309e-04
# Epoch 82/100
# 62/62 [==============================] - 0s 452us/step - loss: 1.3289e-04
# Epoch 83/100
# 62/62 [==============================] - 0s 434us/step - loss: 1.2368e-04
# Epoch 84/100
# 62/62 [==============================] - 0s 438us/step - loss: 1.1577e-04
# Epoch 85/100
# 62/62 [==============================] - 0s 466us/step - loss: 1.1183e-04
# Epoch 86/100
# 62/62 [==============================] - 0s 434us/step - loss: 1.0578e-04
# Epoch 87/100
# 62/62 [==============================] - 0s 466us/step - loss: 1.0009e-04
# Epoch 88/100
# 62/62 [==============================] - 0s 463us/step - loss: 9.6219e-05
# Epoch 89/100
# 62/62 [==============================] - 0s 449us/step - loss: 9.2078e-05
# Epoch 90/100
# 62/62 [==============================] - 0s 450us/step - loss: 8.9185e-05
# Epoch 91/100
# 62/62 [==============================] - 0s 450us/step - loss: 8.6740e-05
# Epoch 92/100
# 62/62 [==============================] - 0s 467us/step - loss: 8.3185e-05
# Epoch 93/100
# 62/62 [==============================] - 0s 482us/step - loss: 8.1633e-05
# Epoch 94/100
# 62/62 [==============================] - 0s 483us/step - loss: 7.7812e-05
# Epoch 95/100
# 62/62 [==============================] - 0s 446us/step - loss: 7.5596e-05
# Epoch 96/100
# 62/62 [==============================] - 0s 466us/step - loss: 7.2881e-05
# Epoch 97/100
# 62/62 [==============================] - 0s 579us/step - loss: 6.9712e-05
# Epoch 98/100
# 62/62 [==============================] - 0s 521us/step - loss: 6.8013e-05
# Epoch 99/100
# 62/62 [==============================] - 0s 496us/step - loss: 6.4034e-05
# Epoch 100/100
# 62/62 [==============================] - 0s 466us/step - loss: 6.2181e-05

# %%
y_train_pred = nn_model.predict(X_train_scaled)
y_test_pred = nn_model.predict(X_test_scaled)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.9999894752589573

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.9999991771893646

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()

# %%
deep_model = tf.keras.models.Sequential()

# %%
deep_model.add(tf.keras.layers.Dense(units=len(X.columns) *2, activation = 'relu', input_dim = len(X.columns)))

# %%
deep_model.add(tf.keras.layers.Dense(units=len(X.columns) *2, activation = 'relu'))

# %%
deep_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
deep_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
deep_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 26)                364
# _________________________________________________________________
# dense_15 (Dense)             (None, 26)                702
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 27
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 1,095
# Trainable params: 1,095
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(loss="mean_squared_error", optimizer="adam")

# %%
deep_model.fit(X_train_scaled, np.asarray(y_train), epochs=100)
# Out:
# Epoch 1/100
# 62/62 [==============================] -
# Epoch 75/100
# 62/62 [==============================] - 0s 643us/step - loss: 3.7354e-05
# Epoch 76/100
# 62/62 [==============================] - 0s 611us/step - loss: 4.4629e-05
# Epoch 77/100
# 62/62 [==============================] - 0s 643us/step - loss: 2.9515e-05
# Epoch 78/100
# 62/62 [==============================] - 0s 660us/step - loss: 2.5702e-05
# Epoch 79/100
# 62/62 [==============================] - 0s 675us/step - loss: 4.6418e-05
# Epoch 80/100
# 62/62 [==============================] - 0s 660us/step - loss: 3.3461e-05
# Epoch 81/100
# 62/62 [==============================] - 0s 708us/step - loss: 3.2636e-05
# Epoch 82/100
# 62/62 [==============================] - 0s 723us/step - loss: 3.5484e-05
# Epoch 83/100
# 62/62 [==============================] - 0s 772us/step - loss: 3.7839e-05
# Epoch 84/100
# 62/62 [==============================] - 0s 708us/step - loss: 5.1558e-05
# Epoch 85/100
# 62/62 [==============================] - 0s 708us/step - loss: 6.7143e-05
# Epoch 86/100
# 62/62 [==============================] - 0s 691us/step - loss: 4.5274e-05
# Epoch 87/100
# 62/62 [==============================] - 0s 644us/step - loss: 4.8204e-05
# Epoch 88/100
# 62/62 [==============================] - 0s 660us/step - loss: 5.4123e-05
# Epoch 89/100
# 62/62 [==============================] - 0s 643us/step - loss: 1.6641e-05
# Epoch 90/100
# 62/62 [==============================] - 0s 643us/step - loss: 9.4238e-05
# Epoch 91/100
# 62/62 [==============================] - 0s 811us/step - loss: 3.8173e-05
# Epoch 92/100
# 62/62 [==============================] - 0s 786us/step - loss: 6.1597e-05
# Epoch 93/100
# 62/62 [==============================] - 0s 788us/step - loss: 3.5684e-05
# Epoch 94/100
# 62/62 [==============================] - 0s 708us/step - loss: 2.1251e-05
# Epoch 95/100
# 62/62 [==============================] - 0s 692us/step - loss: 5.7036e-05
# Epoch 96/100
# 62/62 [==============================] - 0s 699us/step - loss: 5.2765e-05
# Epoch 97/100
# 62/62 [==============================] - 0s 676us/step - loss: 7.4261e-05
# Epoch 98/100
# 62/62 [==============================] - 0s 676us/step - loss: 3.8762e-05
# Epoch 99/100
# 62/62 [==============================] - 0s 676us/step - loss: 1.6406e-04
# Epoch 100/100
# 62/62 [==============================] - 0s 676us/step - loss: 3.9145e-05

# %%
y_train_pred = deep_model.predict(X_train_scaled)
y_test_pred = deep_model.predict(X_test_scaled)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.999997687613853

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.9999969084971021

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train_scaled, y_train)
# Out:
# 1.0

# %%
model.score(X_test_scaled, y_test)
# Out:
# 1.0

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()
