# %%
import tabula
df = tabula.read_pdf('Covid_practice_pdf_extract.pdf', pages = 3, lattice = True)[1]
# Out:
# Got stderr: Dec 06, 2020 8:30:40 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Dec 06, 2020 8:30:40 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Dec 06, 2020 8:30:40 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 376 fonts

# %%
df.head(10)
# Out:
#   Reporting Country/\rTerritory/Area† Total\rconfirmed‡\rcases  \
# 0                                 NaN                    Total
# 1                                 NaN        eporting Country/
# 2                                 NaN               confirmed‡
# 3                                 NaN           erritory/Area†
# 4                                 NaN                    cases
# 5                                 NaN    estern Pacific Region
# 6                               China                    84347
# 7                           Singapore                    14423
# 8                               Japan                    13576
# 9                   Republic of Korea                    10752
#
#   New\rconfirmed\rcases Total\rdeaths      New\rdeaths  \
# 0                   New           NaN              NaN
# 1                 Total           New     Transmission
# 2             confirmed           NaN              NaN
# ...

# %%
df.columns
# Out:
# Index(['Reporting Country/\rTerritory/Area†', 'Total\rconfirmed‡\rcases',
#        'New\rconfirmed\rcases', 'Total\rdeaths', 'New\rdeaths',
#        'Transmission\rclassification§', 'Days since last\rreported case'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace('\r', '')

# %%
data = df.dropna()
data.to_excel('covidd=_data.xlsx')

# %%
data.head()
# Out:
#    Reporting Country/Territory/Area† Totalconfirmed‡cases Newconfirmedcases  \
# 6                              China                84347                 6
# 7                          Singapore                14423               799
# 8                              Japan                13576               191
# 9                  Republic of Korea                10752                14
# 10                       Philippines                 7777               198
#
#    Totaldeaths Newdeaths Transmissionclassification§  \
# 6         4643         0           Clusters of cases
# 7           14         2           Clusters of cases
# 8          376        25           Clusters of cases
# 9          244         1           Clusters of cases
# 10         511        10           Clusters of cases
#
#     Days since lastreported case
# 6                            0.0
# 7                            0.0
# 8                            0.0
# 9                            0.0
# ...
