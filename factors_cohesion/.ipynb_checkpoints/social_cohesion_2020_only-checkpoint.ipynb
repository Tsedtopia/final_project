# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("fsi-2020.xlsx", header=[0])
#pd.read_excel("/tmp/sample.xlsx", usecols = "B:F", skiprows=[0])

# %%
    dictionary = {"key1": "value1"}
print(dictionary["key1"])
# Out:
# value1

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.dtypes)
# Out:
# Country                                     object
# Year                                datetime64[ns]
# Rank                                        object
# Total                                      float64
# C1: Security Apparatus                     float64
# C2: Factionalized Elites                   float64
# C3: Group Grievance                        float64
# E1: Economy                                float64
# E2: Economic Inequality                    float64
# E3: Human Flight and Brain Drain           float64
# P1: State Legitimacy                       float64
# P2: Public Services                        float64
# P3: Human Rights                           float64
# S1: Demographic Pressures                  float64
# S2: Refugees and IDPs                      float64
# X1: External Intervention                  float64
# Change from Previous Year                  float64
# dtype: object

# %%
df
# Out:
#                        Country       Year   Rank       Total  \
# 0                        Yemen 2020-01-01    1st  112.438694
# 1                      Somalia 2020-01-01    2nd  110.888959
# 2                  South Sudan 2020-01-01    3rd  110.752190
# 3                        Syria 2020-01-01    4th  110.749697
# 4    Congo Democratic Republic 2020-01-01    5th  109.394621
# ..                         ...        ...    ...         ...
# 173                    Iceland 2020-01-01  174th   17.800000
# 174                    Denmark 2020-01-01  175th   17.213587
# 175                Switzerland 2020-01-01  176th   17.094086
# 176                     Norway 2020-01-01  177th   16.191210
# 177                    Finland 2020-01-01  178th   14.626666
#
#      C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                  9.700000                      10.0              9.69887
# 1                  9.811328                      10.0              8.60000
# 2                  9.400000                       9.7              9.10000
# 3                  9.900000                       9.9             10.00000
# 4                  8.500000                       9.8              9.70000
# ..                      ...                       ...                  ...
# 173                1.000000                       1.8              0.70000
# 174                1.600000                       1.4              4.00000
# 175                1.400000                       1.0              3.00000
# 176                1.800000                       1.1              3.60000
# 177                2.800000                       1.4              0.90000
#
#      E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0       9.400000                 7.800000                          7.000000
# 1       9.100000                 9.367151                          8.900000
# 2       9.500000                 9.200000                          6.800000
# 3       8.686367                 7.200000                          8.413343
# 4       8.000000                 8.619842                          6.900000
# ..           ...                      ...                               ...
# 173     2.800000                 1.000000                          2.200000
# 174     1.300000                 0.900000                          1.600000
# 175     1.600000                 1.500000                          1.400000
# 176     1.691210                 0.700000                          1.000000
# 177     2.600000                 0.500000                          1.700000
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                9.889823             9.500000          9.950000
# 1                8.888107             9.100000          9.000000
# 2                9.944415             9.500000          9.000000
# 3                9.950000             9.100000         10.000000
# 4                9.660971             9.464911          9.548897
# ..                    ...                  ...               ...
# 173              0.700000             0.700000          0.700000
# 174              0.600000             0.913587          1.400000
# 175              0.500000             1.052499          1.100000
# 176              0.500000             1.100000          0.600000
# 177              0.600000             0.626666          0.500000
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  \
# 0                     9.800000                    9.7
# 1                     9.981087                    9.1
# 2                     9.450357                    9.7
# 3                     7.600000                   10.0
# 4                     9.800000                   10.0
# ..                         ...                    ...
# 173                   1.000000                    1.7
# 174                   1.300000                    1.7
# 175                   1.241587                    2.8
# 176                   0.900000                    2.5
# 177                   0.700000                    1.6
#
#      X1: External Intervention  Change from Previous Year
# 0                    10.000000                  -1.061306
# 1                     9.041286                  -1.311041
# 2                     9.457419                  -1.447810
# 3                     9.999986                  -0.850303
# 4                     9.400000                  -0.805379
# ..                         ...                        ...
# 173                   3.500000                  -2.000000
# 174                   0.500000                  -2.286413
# 175                   0.500000                  -1.605914
# 176                   0.700000                  -1.808790
# 177                   0.700000                  -2.273334
#
# [178 rows x 17 columns]

# %%
# Create dummy variables for the category_columns and merge on the numeric_columns to create an X dataset
# Define target data
# Create category_columns and numeric_columns variables
X = df.drop(['Country', 'Year','Total', 'Rank', 'C2: Factionalized Elites'], axis=1)
X
# Out:
#      C1: Security Apparatus  C3: Group Grievance  E1: Economy  \
# 0                  9.700000              9.69887     9.400000
# 1                  9.811328              8.60000     9.100000
# 2                  9.400000              9.10000     9.500000
# 3                  9.900000             10.00000     8.686367
# 4                  8.500000              9.70000     8.000000
# ..                      ...                  ...          ...
# 173                1.000000              0.70000     2.800000
# 174                1.600000              4.00000     1.300000
# 175                1.400000              3.00000     1.600000
# 176                1.800000              3.60000     1.691210
# 177                2.800000              0.90000     2.600000
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0                   7.800000                          7.000000
# 1                   9.367151                          8.900000
# 2                   9.200000                          6.800000
# 3                   7.200000                          8.413343
# 4                   8.619842                          6.900000
# ..                       ...                               ...
# 173                 1.000000                          2.200000
# 174                 0.900000                          1.600000
# 175                 1.500000                          1.400000
# 176                 0.700000                          1.000000
# 177                 0.500000                          1.700000
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                9.889823             9.500000          9.950000
# 1                8.888107             9.100000          9.000000
# 2                9.944415             9.500000          9.000000
# 3                9.950000             9.100000         10.000000
# 4                9.660971             9.464911          9.548897
# ..                    ...                  ...               ...
# 173              0.700000             0.700000          0.700000
# 174              0.600000             0.913587          1.400000
# 175              0.500000             1.052499          1.100000
# 176              0.500000             1.100000          0.600000
# 177              0.600000             0.626666          0.500000
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  \
# 0                     9.800000                    9.7
# 1                     9.981087                    9.1
# 2                     9.450357                    9.7
# 3                     7.600000                   10.0
# 4                     9.800000                   10.0
# ..                         ...                    ...
# 173                   1.000000                    1.7
# 174                   1.300000                    1.7
# 175                   1.241587                    2.8
# 176                   0.900000                    2.5
# 177                   0.700000                    1.6
#
#      X1: External Intervention  Change from Previous Year
# 0                    10.000000                  -1.061306
# 1                     9.041286                  -1.311041
# 2                     9.457419                  -1.447810
# 3                     9.999986                  -0.850303
# 4                     9.400000                  -0.805379
# ..                         ...                        ...
# 173                   3.500000                  -2.000000
# 174                   0.500000                  -2.286413
# 175                   0.500000                  -1.605914
# 176                   0.700000                  -1.808790
# 177                   0.700000                  -2.273334
#
# [178 rows x 12 columns]

# %%
# Fill in missing values in X with zeroes
X = X.fillna(0)
y = df['C2: Factionalized Elites']

# %%
pd.set_option('display.max_columns', 500)

# %%
X.apply(lambda s: pd.to_numeric(s, errors='coerce').notnull().all())
# Out:
# C1: Security Apparatus              True
# C3: Group Grievance                 True
# E1: Economy                         True
# E2: Economic Inequality             True
# E3: Human Flight and Brain Drain    True
# P1: State Legitimacy                True
# P2: Public Services                 True
# P3: Human Rights                    True
# S1: Demographic Pressures           True
# S2: Refugees and IDPs               True
# X1: External Intervention           True
# Change from Previous Year           True
# dtype: bool

# %%
X.dtypes
# Out:
# C1: Security Apparatus              float64
# C3: Group Grievance                 float64
# E1: Economy                         float64
# E2: Economic Inequality             float64
# E3: Human Flight and Brain Drain    float64
# P1: State Legitimacy                float64
# P2: Public Services                 float64
# P3: Human Rights                    float64
# S1: Demographic Pressures           float64
# S2: Refugees and IDPs               float64
# X1: External Intervention           float64
# Change from Previous Year           float64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=60)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train.head()
# Out:
#      C1: Security Apparatus  C3: Group Grievance  E1: Economy  \
# 171                     3.0                  1.4     1.506904
# 166                     2.4                  3.9     1.824410
# 157                     1.9                  2.8     3.300528
# 56                      6.6                  3.2     7.000000
# 108                     4.9                  3.5     5.400000
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 171                 1.200000                          0.840992
# 166                 1.300000                          2.450243
# 157                 1.400000                          3.050676
# 56                  8.880231                          6.400000
# 108                 5.970653                          7.500000
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 171              0.500000             0.861307          0.600000
# 166              0.700000             0.784854          0.888005
# 157              0.600972             1.345104          3.235009
# 56               6.241423             8.300000          5.804759
# 108              3.300000             6.900000          4.700000
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  \
# 171                   1.300000                    4.6
# 166                   1.612323                    2.9
# 157                   5.700000                    3.5
# 56                    9.203886                    4.2
# 108                   6.787516                    4.3
#
#      X1: External Intervention  Change from Previous Year
# 171                        0.6                  -2.090798
# 166                        0.7                  -1.940165
# 157                        2.9                  -2.067711
# 56                         5.9                  -1.469701
# 108                        6.0                  -1.741831

# %%
nn_model = tf.keras.models.Sequential()

# %%
nn_model.add(tf.keras.layers.Dense(units=len(X.columns) * 2, activation = "relu", input_dim = len(X.columns)))

# %%
nn_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 24)                312
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 337
# Trainable params: 337
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model.compile(loss="mean_squared_error", optimizer="adam")

# %%
nn_model.fit(X_train_scaled, np.asarray(y_train), epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 704us/step - loss: 45.8565
# Epoch 2/100
# 5/5 [==============================] - 0s 599us/step - loss: 43.9386
# Epoch 3/100
# 5/5 [==============================] - 0s 791us/step - loss: 42.0348
# Epoch 4/100
# 5/5 [==============================] - 0s 800us/step - loss: 40.2019
# Epoch 5/100
# 5/5 [==============================] - 0s 798us/step - loss: 38.4553
# Epoch 6/100
# 5/5 [==============================] - 0s 729us/step - loss: 36.7469
# Epoch 7/100
# 5/5 [==============================] - 0s 798us/step - loss: 35.0656
# Epoch 8/100
# 5/5 [==============================] - 0s 598us/step - loss: 33.4264
# Epoch 9/100
# 5/5 [==============================] - 0s 753us/step - loss: 31.8284
# Epoch 10/100
# 5/5 [==============================] - 0s 598us/step - loss: 30.1821
# Epoch 11/100
# 5/5 [==============================] - 0s 598us/step - loss: 28.5731
# Epoch 12/100
# 5/5 [==============================] - 0s 598us/step - loss: 26.9808
# Epoch 13/100
# 5/5 [==============================] - 0s 677us/step - loss: 25.3386
# Epoch 14/100
# 5/5 [==============================] - 0s 683us/step - loss: 23.7078
# Epoch 15/100
# 5/5 [==============================] - 0s 798us/step - loss: 21.9663
# Epoch 16/100
# 5/5 [==============================] - 0s 598us/step - loss: 20.1940
# Epoch 17/100
# 5/5 [==============================] - 0s 399us/step - loss: 18.4640
# Epoch 18/100
# 5/5 [==============================] - 0s 546us/step - loss: 16.8295
# Epoch 19/100
# 5/5 [==============================] - 0s 798us/step - loss: 15.2742
# Epoch 20/100
# 5/5 [==============================] - 0s 598us/step - loss: 13.8441
# Epoch 21/100
# 5/5 [==============================] - 0s 688us/step - loss: 12.5007
# Epoch 22/100
# 5/5 [==============================] - 0s 599us/step - loss: 11.2335
# Epoch 23/100
# 5/5 [==============================] - 0s 598us/step - loss: 9.9924
# Epoch 24/100
# 5/5 [==============================] - 0s 543us/step - loss: 8.9508
# Epoch 25/100
# 5/5 [==============================] - 0s 598us/step - loss: 7.9432
# Epoch 26/100
# 5/5 [==============================] - 0s 676us/step - loss: 7.0635
# Epoch 27/100
# 5/5 [==============================] - 0s 598us/step - loss: 6.2397
# Epoch 28/100
# 5/5 [==============================] - 0s 664us/step - loss: 5.5256
# Epoch 29/100
# 5/5 [==============================] - 0s 673us/step - loss: 4.8908
# Epoch 30/100
# 5/5 [==============================] - 0s 768us/step - loss: 4.3150
# Epoch 31/100
# 5/5 [==============================] - 0s 598us/step - loss: 3.8657
# Epoch 32/100
# 5/5 [==============================] - 0s 598us/step - loss: 3.4731
# Epoch 33/100
# 5/5 [==============================] - 0s 752us/step - loss: 3.1436
# Epoch 34/100
# 5/5 [==============================] - 0s 599us/step - loss: 2.8442
# Epoch 35/100
# 5/5 [==============================] - 0s 598us/step - loss: 2.6237
# Epoch 36/100
# 5/5 [==============================] - 0s 930us/step - loss: 2.4249
# Epoch 37/100
# 5/5 [==============================] - 0s 734us/step - loss: 2.2843
# Epoch 38/100
# 5/5 [==============================] - 0s 798us/step - loss: 2.1767
# Epoch 39/100
# 5/5 [==============================] - 0s 798us/step - loss: 2.0932
# Epoch 40/100
# 5/5 [==============================] - 0s 997us/step - loss: 2.0302
# Epoch 41/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.9802
# Epoch 42/100
# 5/5 [==============================] - 0s 774us/step - loss: 1.9348
# Epoch 43/100
# 5/5 [==============================] - 0s 799us/step - loss: 1.9075
# Epoch 44/100
# 5/5 [==============================] - 0s 791us/step - loss: 1.8794
# Epoch 45/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.8621
# Epoch 46/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.8462
# Epoch 47/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.8350
# Epoch 48/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.8231
# Epoch 49/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.8150
# Epoch 50/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.8087
# Epoch 51/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.8034
# Epoch 52/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7981
# Epoch 53/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7934
# Epoch 54/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.7882
# Epoch 55/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7839
# Epoch 56/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7795
# Epoch 57/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7749
# Epoch 58/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7710
# Epoch 59/100
# 5/5 [==============================] - 0s 521us/step - loss: 1.7664
# Epoch 60/100
# 5/5 [==============================] - 0s 763us/step - loss: 1.7626
# Epoch 61/100
# 5/5 [==============================] - 0s 755us/step - loss: 1.7574
# Epoch 62/100
# 5/5 [==============================] - 0s 674us/step - loss: 1.7524
# Epoch 63/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.7477
# Epoch 64/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7432
# Epoch 65/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.7379
# Epoch 66/100
# 5/5 [==============================] - 0s 756us/step - loss: 1.7326
# Epoch 67/100
# 5/5 [==============================] - 0s 594us/step - loss: 1.7283
# Epoch 68/100
# 5/5 [==============================] - 0s 797us/step - loss: 1.7227
# Epoch 69/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.7176
# Epoch 70/100
# 5/5 [==============================] - 0s 792us/step - loss: 1.7121
# Epoch 71/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.7057
# Epoch 72/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.6986
# Epoch 73/100
# 5/5 [==============================] - 0s 804us/step - loss: 1.6934
# Epoch 74/100
# 5/5 [==============================] - 0s 805us/step - loss: 1.6856
# Epoch 75/100
# 5/5 [==============================] - 0s 792us/step - loss: 1.6785
# Epoch 76/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.6718
# Epoch 77/100
# 5/5 [==============================] - 0s 579us/step - loss: 1.6647
# Epoch 78/100
# 5/5 [==============================] - 0s 806us/step - loss: 1.6570
# Epoch 79/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.6490
# Epoch 80/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.6416
# Epoch 81/100
# 5/5 [==============================] - 0s 792us/step - loss: 1.6313
# Epoch 82/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.6249
# Epoch 83/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.6165
# Epoch 84/100
# 5/5 [==============================] - 0s 670us/step - loss: 1.6083
# Epoch 85/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.5994
# Epoch 86/100
# 5/5 [==============================] - 0s 791us/step - loss: 1.5911
# Epoch 87/100
# 5/5 [==============================] - 0s 794us/step - loss: 1.5837
# Epoch 88/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.5756
# Epoch 89/100
# 5/5 [==============================] - 0s 588us/step - loss: 1.5695
# Epoch 90/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.5609
# Epoch 91/100
# 5/5 [==============================] - 0s 856us/step - loss: 1.5534
# Epoch 92/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.5456
# Epoch 93/100
# 5/5 [==============================] - 0s 698us/step - loss: 1.5391
# Epoch 94/100
# 5/5 [==============================] - 0s 527us/step - loss: 1.5329
# Epoch 95/100
# 5/5 [==============================] - 0s 779us/step - loss: 1.5272
# Epoch 96/100
# 5/5 [==============================] - 0s 792us/step - loss: 1.5204
# Epoch 97/100
# 5/5 [==============================] - 0s 827us/step - loss: 1.5157
# Epoch 98/100
# 5/5 [==============================] - 0s 607us/step - loss: 1.5119
# Epoch 99/100
# 5/5 [==============================] - 0s 692us/step - loss: 1.5068
# Epoch 100/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5016

# %%
y_train_pred = nn_model.predict(X_train_scaled)
y_test_pred = nn_model.predict(X_test_scaled)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.7502612318051813

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.6338499360474185

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()

# %%
deep_model = tf.keras.models.Sequential()

# %%
deep_model.add(tf.keras.layers.Dense(units=len(X.columns) *2, activation = 'relu', input_dim = len(X.columns)))

# %%
deep_model.add(tf.keras.layers.Dense(units=len(X.columns) *2, activation = 'relu'))

# %%
deep_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
deep_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 24)                312
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 25
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 939
# Trainable params: 939
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(loss="mean_squared_error", optimizer="adam")

# %%
deep_model.fit(X_train_scaled, np.asarray(y_train), epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 3ms/step - loss: 49.1457
# Epoch 2/100
# 5/5 [==============================] - 0s 798us/step - loss: 45.5716
# Epoch 3/100
# 5/5 [==============================] - 0s 780us/step - loss: 42.3812
# Epoch 4/100
# 5/5 [==============================] - 0s 598us/step - loss: 39.1473
# Epoch 5/100
# 5/5 [==============================] - 0s 798us/step - loss: 35.9435
# Epoch 6/100
# 5/5 [==============================] - 0s 713us/step - loss: 32.6811
# Epoch 7/100
# 5/5 [==============================] - 0s 607us/step - loss: 29.3807
# Epoch 8/100
# 5/5 [==============================] - 0s 598us/step - loss: 26.0185
# Epoch 9/100
# 5/5 [==============================] - 0s 599us/step - loss: 22.6231
# Epoch 10/100
# 5/5 [==============================] - 0s 798us/step - loss: 19.3531
# Epoch 11/100
# 5/5 [==============================] - 0s 598us/step - loss: 15.7900
# Epoch 12/100
# 5/5 [==============================] - 0s 612us/step - loss: 12.3847
# Epoch 13/100
# 5/5 [==============================] - 0s 592us/step - loss: 9.2345
# Epoch 14/100
# 5/5 [==============================] - 0s 772us/step - loss: 6.5677
# Epoch 15/100
# 5/5 [==============================] - 0s 599us/step - loss: 4.3180
# Epoch 16/100
# 5/5 [==============================] - 0s 600us/step - loss: 2.7775
# Epoch 17/100
# 5/5 [==============================] - 0s 792us/step - loss: 1.9528
# Epoch 18/100
# 5/5 [==============================] - 0s 596us/step - loss: 1.7124
# Epoch 19/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7210
# Epoch 20/100
# 5/5 [==============================] - 0s 804us/step - loss: 1.7778
# Epoch 21/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.7623
# Epoch 22/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7114
# Epoch 23/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.6745
# Epoch 24/100
# 5/5 [==============================] - 0s 828us/step - loss: 1.6536
# Epoch 25/100
# 5/5 [==============================] - 0s 712us/step - loss: 1.6451
# Epoch 26/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.6383
# Epoch 27/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.6313
# Epoch 28/100
# 5/5 [==============================] - 0s 791us/step - loss: 1.6240
# Epoch 29/100
# 5/5 [==============================] - 0s 991us/step - loss: 1.6144
# Epoch 30/100
# 5/5 [==============================] - 0s 758us/step - loss: 1.6061
# Epoch 31/100
# 5/5 [==============================] - 0s 884us/step - loss: 1.5945
# Epoch 32/100
# 5/5 [==============================] - 0s 805us/step - loss: 1.5826
# Epoch 33/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.5728
# Epoch 34/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5644
# Epoch 35/100
# 5/5 [==============================] - 0s 991us/step - loss: 1.5563
# Epoch 36/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.5499
# Epoch 37/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.5494
# Epoch 38/100
# 5/5 [==============================] - 0s 818us/step - loss: 1.5423
# Epoch 39/100
# 5/5 [==============================] - 0s 990us/step - loss: 1.5348
# Epoch 40/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.5202
# Epoch 41/100
# 5/5 [==============================] - 0s 799us/step - loss: 1.5002
# Epoch 42/100
# 5/5 [==============================] - 0s 792us/step - loss: 1.4934
# Epoch 43/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.4844
# Epoch 44/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.4755
# Epoch 45/100
# 5/5 [==============================] - 0s 635us/step - loss: 1.4690
# Epoch 46/100
# 5/5 [==============================] - 0s 782us/step - loss: 1.4595
# Epoch 47/100
# 5/5 [==============================] - 0s 791us/step - loss: 1.4518
# Epoch 48/100
# 5/5 [==============================] - 0s 884us/step - loss: 1.4428
# Epoch 49/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.4294
# Epoch 50/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.4102
# Epoch 51/100
# 5/5 [==============================] - 0s 716us/step - loss: 1.3893
# Epoch 52/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.3802
# Epoch 53/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.3463
# Epoch 54/100
# 5/5 [==============================] - 0s 775us/step - loss: 1.3299
# Epoch 55/100
# 5/5 [==============================] - 0s 992us/step - loss: 1.3233
# Epoch 56/100
# 5/5 [==============================] - 0s 604us/step - loss: 1.2971
# Epoch 57/100
# 5/5 [==============================] - 0s 791us/step - loss: 1.2740
# Epoch 58/100
# 5/5 [==============================] - 0s 792us/step - loss: 1.2500
# Epoch 59/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.2425
# Epoch 60/100
# 5/5 [==============================] - 0s 925us/step - loss: 1.2259
# Epoch 61/100
# 5/5 [==============================] - 0s 747us/step - loss: 1.2090
# Epoch 62/100
# 5/5 [==============================] - 0s 656us/step - loss: 1.2016
# Epoch 63/100
# 5/5 [==============================] - 0s 736us/step - loss: 1.2038
# Epoch 64/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.2044
# Epoch 65/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.1781
# Epoch 66/100
# 5/5 [==============================] - 0s 753us/step - loss: 1.1530
# Epoch 67/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.1489
# Epoch 68/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.1495
# Epoch 69/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.1346
# Epoch 70/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.1273
# Epoch 71/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.1136
# Epoch 72/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.1051
# Epoch 73/100
# 5/5 [==============================] - 0s 669us/step - loss: 1.0971
# Epoch 74/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0849
# Epoch 75/100
# 5/5 [==============================] - 0s 799us/step - loss: 1.0745
# Epoch 76/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0626
# Epoch 77/100
# 5/5 [==============================] - 0s 803us/step - loss: 1.0634
# Epoch 78/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0546
# Epoch 79/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0408
# Epoch 80/100
# 5/5 [==============================] - 0s 594us/step - loss: 1.0465
# Epoch 81/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0434
# Epoch 82/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0276
# Epoch 83/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.0141
# Epoch 84/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0126
# Epoch 85/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0149
# Epoch 86/100
# 5/5 [==============================] - 0s 791us/step - loss: 1.0033
# Epoch 87/100
# 5/5 [==============================] - 0s 998us/step - loss: 0.9966
# Epoch 88/100
# 5/5 [==============================] - 0s 798us/step - loss: 0.9867
# Epoch 89/100
# 5/5 [==============================] - 0s 798us/step - loss: 0.9891
# Epoch 90/100
# 5/5 [==============================] - 0s 707us/step - loss: 0.9764
# Epoch 91/100
# 5/5 [==============================] - 0s 798us/step - loss: 0.9859
# Epoch 92/100
# 5/5 [==============================] - 0s 710us/step - loss: 0.9796
# Epoch 93/100
# 5/5 [==============================] - 0s 798us/step - loss: 0.9664
# Epoch 94/100
# 5/5 [==============================] - 0s 766us/step - loss: 0.9674
# Epoch 95/100
# 5/5 [==============================] - 0s 794us/step - loss: 0.9626
# Epoch 96/100
# 5/5 [==============================] - 0s 916us/step - loss: 0.9516
# Epoch 97/100
# 5/5 [==============================] - 0s 807us/step - loss: 0.9494
# Epoch 98/100
# 5/5 [==============================] - 0s 998us/step - loss: 0.9517
# Epoch 99/100
# 5/5 [==============================] - 0s 798us/step - loss: 0.9472
# Epoch 100/100
# 5/5 [==============================] - 0s 867us/step - loss: 0.9414

# %%
y_train_pred = deep_model.predict(X_train_scaled)
y_test_pred = deep_model.predict(X_test_scaled)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.8449147999770001

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.7577424227842218

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train_scaled, y_train)
# Out:
# 0.8665000965222467

# %%
model.score(X_test_scaled, y_test)
# Out:
# 0.7087415790368

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()
