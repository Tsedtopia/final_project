# %%
import os
import pandas as pd
cwd = os.getcwd() 
files = os.listdir(cwd) 
print(files)
# Out:
# ['.ipynb_checkpoints', 'Data Science Final Project.pptx', 'final_project', 'Fragile states index _ The fund for peace.docx', 'fragile_state_index.xlsx', 'fragile_state_index_sort_USA_ET.xlsx', 'fsi-2006.xlsx', 'fsi-2007.xlsx', 'fsi-2008.xlsx', 'fsi-2009.xlsx', 'fsi-2010.xlsx', 'fsi-2011.xlsx', 'fsi-2012.xlsx', 'fsi-2013.xlsx', 'fsi-2014.xlsx', 'fsi-2015.xlsx', 'fsi-2016.xlsx', 'fsi-2017.xlsx', 'fsi-2018.xlsx', 'fsi-2019.xlsx', 'fsi-2020.xlsx', 'merging_fsi_years.ipynb', 'social_cohesion_2020_only.ipynb', 'social_cohesion_2020_Pvalue_added.ipynb', 'social_cohesion_C2.ipynb', 'social_cohesion_C3.ipynb', 'social_cohesion_E2.ipynb', 'social_cohesion_P3.ipynb', '~$Data Science Final Project.pptx']

# %%
df = pd.DataFrame()
for file in files:
     if file.endswith('.xlsx'):
        df = df.append(pd.read_excel(file), ignore_index=True) 
        print(file)
#df.head()
# Out:
# fragile_state_index.xlsx
# fragile_state_index_sort_USA_ET.xlsx
# fsi-2006.xlsx
# fsi-2007.xlsx
# fsi-2008.xlsx
# fsi-2009.xlsx
# fsi-2010.xlsx
# fsi-2011.xlsx
# fsi-2012.xlsx
# fsi-2013.xlsx
# fsi-2014.xlsx
# fsi-2015.xlsx
# fsi-2016.xlsx
# fsi-2017.xlsx
# fsi-2018.xlsx
# fsi-2019.xlsx
# fsi-2020.xlsx

# %%
df
# Out:
#       Unnamed: 0                    Country                 Year   Rank  \
# 0            0.0                      Sudan                 2006    1st
# 1            1.0  Congo Democratic Republic                 2006    2nd
# 2            2.0              Cote d'Ivoire                 2006    3rd
# 3            3.0                       Iraq                 2006    4th
# 4            4.0                   Zimbabwe                 2006    5th
# ...          ...                        ...                  ...    ...
# 5291         NaN                    Iceland  2020-01-01 00:00:00  174th
# 5292         NaN                    Denmark  2020-01-01 00:00:00  175th
# 5293         NaN                Switzerland  2020-01-01 00:00:00  176th
# 5294         NaN                     Norway  2020-01-01 00:00:00  177th
# 5295         NaN                    Finland  2020-01-01 00:00:00  178th
#
#            Total  C1: Security Apparatus  C2: Factionalized Elites  \
# 0     112.300000                     9.8                       9.1
# 1     110.100000                     9.8                       9.6
# 2     109.200000                     9.8                       9.8
# 3     109.000000                     9.8                       9.7
# 4     108.900000                     9.4                       8.5
# ...          ...                     ...                       ...
# 5291   17.800000                     1.0                       1.8
# 5292   17.213587                     1.6                       1.4
# 5293   17.094086                     1.4                       1.0
# 5294   16.191210                     1.8                       1.1
# 5295   14.626666                     2.8                       1.4
#
#       C3: Group Grievance  E1: Economy  E2: Economic Inequality  \
# 0                     9.7      7.50000                      9.2
# 1                     9.1      8.10000                      9.0
# 2                     9.8      9.00000                      8.0
# 3                     9.8      8.20000                      8.7
# 4                     8.5      9.80000                      9.2
# ...                   ...          ...                      ...
# 5291                  0.7      2.80000                      1.0
# 5292                  4.0      1.30000                      0.9
# 5293                  3.0      1.60000                      1.5
# 5294                  3.6      1.69121                      0.7
# 5295                  0.9      2.60000                      0.5
#
#       E3: Human Flight and Brain Drain  P1: State Legitimacy  \
# 0                                  9.1                   9.5
# 1                                  8.0                   9.0
# 2                                  8.5                  10.0
# 3                                  9.1                   8.5
# 4                                  9.0                   8.9
# ...                                ...                   ...
# 5291                               2.2                   0.7
# 5292                               1.6                   0.6
# 5293                               1.4                   0.5
# 5294                               1.0                   0.5
# 5295                               1.7                   0.6
#
#       P2: Public Services  P3: Human Rights  S1: Demographic Pressures  \
# 0                9.500000               9.8                   9.600000
# 1                9.000000               9.5                   9.500000
# 2                8.500000               9.4                   8.800000
# 3                8.300000               9.7                   8.900000
# 4                9.500000               9.5                   9.700000
# ...                   ...               ...                        ...
# 5291             0.700000               0.7                   1.000000
# 5292             0.913587               1.4                   1.300000
# 5293             1.052499               1.1                   1.241587
# 5294             1.100000               0.6                   0.900000
# 5295             0.626666               0.5                   0.700000
#
#       S2: Refugees and IDPs  X1: External Intervention  \
# 0                       9.7                        9.8
# 1                       9.5                       10.0
# 2                       7.6                       10.0
# 3                       8.3                       10.0
# 4                       8.9                        8.0
# ...                     ...                        ...
# 5291                    1.7                        3.5
# 5292                    1.7                        0.5
# 5293                    2.8                        0.5
# 5294                    2.5                        0.7
# 5295                    1.6                        0.7
#
#       Change from Previous Year
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 5291                  -2.000000
# 5292                  -2.286413
# 5293                  -1.605914
# 5294                  -1.808790
# 5295                  -2.273334
#
# [5296 rows x 18 columns]

# %%
df.to_excel('fragile_state_index.xlsx')
