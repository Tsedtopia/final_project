# %%
import os
import pandas as pd
cwd = os.getcwd() 
files = os.listdir(cwd) 
print(files)
# Out:
# ['.ipynb_checkpoints', 'Data Science Final Project.pptx', 'final_project', 'Fragile states index _ The fund for peace.docx', 'fsi-2006.xlsx', 'fsi-2007.xlsx', 'fsi-2008.xlsx', 'fsi-2009.xlsx', 'fsi-2010.xlsx', 'fsi-2011.xlsx', 'fsi-2012.xlsx', 'fsi-2013.xlsx', 'fsi-2014.xlsx', 'fsi-2015.xlsx', 'fsi-2016.xlsx', 'fsi-2017.xlsx', 'fsi-2018.xlsx', 'fsi-2019.xlsx', 'fsi-2020.xlsx', 'merging_fsi_years.ipynb', 'social_cohesion.ipynb', '~$agile states index _ The fund for peace.docx', '~$Data Science Final Project.pptx']

# %%
df = pd.DataFrame()
for file in files:
     if file.endswith('.xlsx'):
        df = df.append(pd.read_excel(file), ignore_index=True) 
        print(file)
#df.head()
# Out:
# fsi-2006.xlsx
# fsi-2007.xlsx
# fsi-2008.xlsx
# fsi-2009.xlsx
# fsi-2010.xlsx
# fsi-2011.xlsx
# fsi-2012.xlsx
# fsi-2013.xlsx
# fsi-2014.xlsx
# fsi-2015.xlsx
# fsi-2016.xlsx
# fsi-2017.xlsx
# fsi-2018.xlsx
# fsi-2019.xlsx
# fsi-2020.xlsx

# %%
df
# Out:
#                         Country       Year   Rank       Total  \
# 0                         Sudan 2006-01-01    1st  112.300000
# 1     Congo Democratic Republic 2006-01-01    2nd  110.100000
# 2                 Cote d'Ivoire 2006-01-01    3rd  109.200000
# 3                          Iraq 2006-01-01    4th  109.000000
# 4                      Zimbabwe 2006-01-01    5th  108.900000
# ...                         ...        ...    ...         ...
# 2628                    Iceland 2020-01-01  174th   17.800000
# 2629                    Denmark 2020-01-01  175th   17.213587
# 2630                Switzerland 2020-01-01  176th   17.094086
# 2631                     Norway 2020-01-01  177th   16.191210
# 2632                    Finland 2020-01-01  178th   14.626666
#
#       C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                        9.8                       9.1                  9.7
# ...

# %%
df.to_excel('fragile_state_index.xlsx')
