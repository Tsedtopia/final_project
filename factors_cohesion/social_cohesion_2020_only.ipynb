# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("fsi-2020.xlsx", header=[0])
#pd.read_excel("/tmp/sample.xlsx", usecols = "B:F", skiprows=[0])

# %%
    dictionary = {"key1": "value1"}
print(dictionary["key1"])
# Out:
# value1

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.dtypes)
# Out:
# Country                                     object
# Year                                datetime64[ns]
# Rank                                        object
# Total                                      float64
# C1: Security Apparatus                     float64
# C2: Factionalized Elites                   float64
# C3: Group Grievance                        float64
# E1: Economy                                float64
# E2: Economic Inequality                    float64
# E3: Human Flight and Brain Drain           float64
# P1: State Legitimacy                       float64
# P2: Public Services                        float64
# P3: Human Rights                           float64
# S1: Demographic Pressures                  float64
# S2: Refugees and IDPs                      float64
# X1: External Intervention                  float64
# Change from Previous Year                  float64
# dtype: object

# %%
df
# Out:
#                        Country       Year   Rank       Total  \
# 0                        Yemen 2020-01-01    1st  112.438694
# 1                      Somalia 2020-01-01    2nd  110.888959
# 2                  South Sudan 2020-01-01    3rd  110.752190
# 3                        Syria 2020-01-01    4th  110.749697
# 4    Congo Democratic Republic 2020-01-01    5th  109.394621
# ..                         ...        ...    ...         ...
# 173                    Iceland 2020-01-01  174th   17.800000
# 174                    Denmark 2020-01-01  175th   17.213587
# 175                Switzerland 2020-01-01  176th   17.094086
# 176                     Norway 2020-01-01  177th   16.191210
# 177                    Finland 2020-01-01  178th   14.626666
#
#      C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                  9.700000                      10.0              9.69887
# 1                  9.811328                      10.0              8.60000
# 2                  9.400000                       9.7              9.10000
# 3                  9.900000                       9.9             10.00000
# 4                  8.500000                       9.8              9.70000
# ..                      ...                       ...                  ...
# 173                1.000000                       1.8              0.70000
# 174                1.600000                       1.4              4.00000
# 175                1.400000                       1.0              3.00000
# 176                1.800000                       1.1              3.60000
# 177                2.800000                       1.4              0.90000
#
#      E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0       9.400000                 7.800000                          7.000000
# 1       9.100000                 9.367151                          8.900000
# 2       9.500000                 9.200000                          6.800000
# 3       8.686367                 7.200000                          8.413343
# 4       8.000000                 8.619842                          6.900000
# ..           ...                      ...                               ...
# 173     2.800000                 1.000000                          2.200000
# 174     1.300000                 0.900000                          1.600000
# 175     1.600000                 1.500000                          1.400000
# 176     1.691210                 0.700000                          1.000000
# 177     2.600000                 0.500000                          1.700000
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                9.889823             9.500000          9.950000
# 1                8.888107             9.100000          9.000000
# 2                9.944415             9.500000          9.000000
# 3                9.950000             9.100000         10.000000
# 4                9.660971             9.464911          9.548897
# ..                    ...                  ...               ...
# 173              0.700000             0.700000          0.700000
# 174              0.600000             0.913587          1.400000
# 175              0.500000             1.052499          1.100000
# 176              0.500000             1.100000          0.600000
# 177              0.600000             0.626666          0.500000
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  \
# 0                     9.800000                    9.7
# 1                     9.981087                    9.1
# 2                     9.450357                    9.7
# 3                     7.600000                   10.0
# 4                     9.800000                   10.0
# ..                         ...                    ...
# 173                   1.000000                    1.7
# 174                   1.300000                    1.7
# 175                   1.241587                    2.8
# 176                   0.900000                    2.5
# 177                   0.700000                    1.6
#
#      X1: External Intervention  Change from Previous Year
# 0                    10.000000                  -1.061306
# 1                     9.041286                  -1.311041
# 2                     9.457419                  -1.447810
# 3                     9.999986                  -0.850303
# 4                     9.400000                  -0.805379
# ..                         ...                        ...
# 173                   3.500000                  -2.000000
# 174                   0.500000                  -2.286413
# 175                   0.500000                  -1.605914
# 176                   0.700000                  -1.808790
# 177                   0.700000                  -2.273334
#
# [178 rows x 17 columns]

# %%
# Create dummy variables for the category_columns and merge on the numeric_columns to create an X dataset
# Define target data
# Create category_columns and numeric_columns variables
X = df.drop(['Country', 'Year','Total', 'Rank', 'C2: Factionalized Elites'], axis=1)
X
# Out:
#      C1: Security Apparatus  C3: Group Grievance  E1: Economy  \
# 0                  9.700000              9.69887     9.400000
# 1                  9.811328              8.60000     9.100000
# 2                  9.400000              9.10000     9.500000
# 3                  9.900000             10.00000     8.686367
# 4                  8.500000              9.70000     8.000000
# ..                      ...                  ...          ...
# 173                1.000000              0.70000     2.800000
# 174                1.600000              4.00000     1.300000
# 175                1.400000              3.00000     1.600000
# 176                1.800000              3.60000     1.691210
# 177                2.800000              0.90000     2.600000
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0                   7.800000                          7.000000
# 1                   9.367151                          8.900000
# 2                   9.200000                          6.800000
# 3                   7.200000                          8.413343
# 4                   8.619842                          6.900000
# ..                       ...                               ...
# 173                 1.000000                          2.200000
# 174                 0.900000                          1.600000
# 175                 1.500000                          1.400000
# 176                 0.700000                          1.000000
# 177                 0.500000                          1.700000
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                9.889823             9.500000          9.950000
# 1                8.888107             9.100000          9.000000
# 2                9.944415             9.500000          9.000000
# 3                9.950000             9.100000         10.000000
# 4                9.660971             9.464911          9.548897
# ..                    ...                  ...               ...
# 173              0.700000             0.700000          0.700000
# 174              0.600000             0.913587          1.400000
# 175              0.500000             1.052499          1.100000
# 176              0.500000             1.100000          0.600000
# 177              0.600000             0.626666          0.500000
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  \
# 0                     9.800000                    9.7
# 1                     9.981087                    9.1
# 2                     9.450357                    9.7
# 3                     7.600000                   10.0
# 4                     9.800000                   10.0
# ..                         ...                    ...
# 173                   1.000000                    1.7
# 174                   1.300000                    1.7
# 175                   1.241587                    2.8
# 176                   0.900000                    2.5
# 177                   0.700000                    1.6
#
#      X1: External Intervention  Change from Previous Year
# 0                    10.000000                  -1.061306
# 1                     9.041286                  -1.311041
# 2                     9.457419                  -1.447810
# 3                     9.999986                  -0.850303
# 4                     9.400000                  -0.805379
# ..                         ...                        ...
# 173                   3.500000                  -2.000000
# 174                   0.500000                  -2.286413
# 175                   0.500000                  -1.605914
# 176                   0.700000                  -1.808790
# 177                   0.700000                  -2.273334
#
# [178 rows x 12 columns]

# %%
# Fill in missing values in X with zeroes
X = X.fillna(0)
y = df['C2: Factionalized Elites']

# %%
pd.set_option('display.max_columns', 500)

# %%
X.apply(lambda s: pd.to_numeric(s, errors='coerce').notnull().all())
# Out:
# C1: Security Apparatus              True
# C3: Group Grievance                 True
# E1: Economy                         True
# E2: Economic Inequality             True
# E3: Human Flight and Brain Drain    True
# P1: State Legitimacy                True
# P2: Public Services                 True
# P3: Human Rights                    True
# S1: Demographic Pressures           True
# S2: Refugees and IDPs               True
# X1: External Intervention           True
# Change from Previous Year           True
# dtype: bool

# %%
X.dtypes
# Out:
# C1: Security Apparatus              float64
# C3: Group Grievance                 float64
# E1: Economy                         float64
# E2: Economic Inequality             float64
# E3: Human Flight and Brain Drain    float64
# P1: State Legitimacy                float64
# P2: Public Services                 float64
# P3: Human Rights                    float64
# S1: Demographic Pressures           float64
# S2: Refugees and IDPs               float64
# X1: External Intervention           float64
# Change from Previous Year           float64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=60)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train.head()
# Out:
#      C1: Security Apparatus  C3: Group Grievance  E1: Economy  \
# 171                     3.0                  1.4     1.506904
# 166                     2.4                  3.9     1.824410
# 157                     1.9                  2.8     3.300528
# 56                      6.6                  3.2     7.000000
# 108                     4.9                  3.5     5.400000
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 171                 1.200000                          0.840992
# 166                 1.300000                          2.450243
# 157                 1.400000                          3.050676
# 56                  8.880231                          6.400000
# 108                 5.970653                          7.500000
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 171              0.500000             0.861307          0.600000
# 166              0.700000             0.784854          0.888005
# 157              0.600972             1.345104          3.235009
# 56               6.241423             8.300000          5.804759
# 108              3.300000             6.900000          4.700000
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  \
# 171                   1.300000                    4.6
# 166                   1.612323                    2.9
# 157                   5.700000                    3.5
# 56                    9.203886                    4.2
# 108                   6.787516                    4.3
#
#      X1: External Intervention  Change from Previous Year
# 171                        0.6                  -2.090798
# 166                        0.7                  -1.940165
# 157                        2.9                  -2.067711
# 56                         5.9                  -1.469701
# 108                        6.0                  -1.741831

# %%
nn_model = tf.keras.models.Sequential()

# %%
nn_model.add(tf.keras.layers.Dense(units=len(X.columns) * 2, activation = "relu", input_dim = len(X.columns)))

# %%
nn_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 24)                312
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 337
# Trainable params: 337
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model.compile(loss="mean_squared_error", optimizer="adam")

# %%
nn_model.fit(X_train_scaled, np.asarray(y_train), epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 978us/step - loss: 48.9658
# Epoch 2/100
# 5/5 [==============================] - 0s 596us/step - loss: 47.0264
# Epoch 3/100
# 5/5 [==============================] - 0s 798us/step - loss: 45.1048
# Epoch 4/100
# 5/5 [==============================] - 0s 798us/step - loss: 43.2577
# Epoch 5/100
# 5/5 [==============================] - 0s 612us/step - loss: 41.3529
# Epoch 6/100
# 5/5 [==============================] - 0s 998us/step - loss: 39.4578
# Epoch 7/100
# 5/5 [==============================] - 0s 591us/step - loss: 37.5244
# Epoch 8/100
# 5/5 [==============================] - 0s 590us/step - loss: 35.6292
# Epoch 9/100
# 5/5 [==============================] - 0s 481us/step - loss: 33.7448
# Epoch 10/100
# 5/5 [==============================] - 0s 801us/step - loss: 31.8228
# Epoch 11/100
# 5/5 [==============================] - 0s 997us/step - loss: 29.9341
# Epoch 12/100
# 5/5 [==============================] - 0s 598us/step - loss: 28.1220
# Epoch 13/100
# 5/5 [==============================] - 0s 999us/step - loss: 26.2375
# Epoch 14/100
# 5/5 [==============================] - 0s 608us/step - loss: 24.4644
# Epoch 15/100
# 5/5 [==============================] - 0s 808us/step - loss: 22.7265
# Epoch 16/100
# 5/5 [==============================] - 0s 998us/step - loss: 20.9958
# Epoch 17/100
# 5/5 [==============================] - 0s 597us/step - loss: 19.3951
# Epoch 18/100
# 5/5 [==============================] - 0s 798us/step - loss: 17.7096
# Epoch 19/100
# 5/5 [==============================] - 0s 592us/step - loss: 16.1988
# Epoch 20/100
# 5/5 [==============================] - 0s 798us/step - loss: 14.7714
# Epoch 21/100
# 5/5 [==============================] - 0s 798us/step - loss: 13.3479
# Epoch 22/100
# 5/5 [==============================] - 0s 804us/step - loss: 12.0413
# Epoch 23/100
# 5/5 [==============================] - 0s 888us/step - loss: 10.8285
# Epoch 24/100
# 5/5 [==============================] - 0s 472us/step - loss: 9.6525
# Epoch 25/100
# 5/5 [==============================] - 0s 798us/step - loss: 8.5624
# Epoch 26/100
# 5/5 [==============================] - 0s 798us/step - loss: 7.6123
# Epoch 27/100
# 5/5 [==============================] - 0s 798us/step - loss: 6.7064
# Epoch 28/100
# 5/5 [==============================] - 0s 1ms/step - loss: 5.9352
# Epoch 29/100
# 5/5 [==============================] - 0s 598us/step - loss: 5.2236
# Epoch 30/100
# 5/5 [==============================] - 0s 978us/step - loss: 4.5750
# Epoch 31/100
# 5/5 [==============================] - 0s 591us/step - loss: 4.0213
# Epoch 32/100
# 5/5 [==============================] - 0s 858us/step - loss: 3.5519
# Epoch 33/100
# 5/5 [==============================] - 0s 799us/step - loss: 3.1356
# Epoch 34/100
# 5/5 [==============================] - 0s 593us/step - loss: 2.8088
# Epoch 35/100
# 5/5 [==============================] - 0s 997us/step - loss: 2.5277
# Epoch 36/100
# 5/5 [==============================] - 0s 792us/step - loss: 2.3006
# Epoch 37/100
# 5/5 [==============================] - 0s 998us/step - loss: 2.1154
# Epoch 38/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.9788
# Epoch 39/100
# 5/5 [==============================] - 0s 601us/step - loss: 1.8764
# Epoch 40/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7876
# Epoch 41/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.7325
# Epoch 42/100
# 5/5 [==============================] - ETA: 0s - loss: 2.226 - 0s 997us/step - loss: 1.6852
# Epoch 43/100
# 5/5 [==============================] - 0s 980us/step - loss: 1.6594
# Epoch 44/100
# 5/5 [==============================] - 0s 840us/step - loss: 1.6364
# Epoch 45/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.6196
# Epoch 46/100
# 5/5 [==============================] - 0s 826us/step - loss: 1.6069
# Epoch 47/100
# 5/5 [==============================] - 0s 807us/step - loss: 1.5963
# Epoch 48/100
# 5/5 [==============================] - 0s 989us/step - loss: 1.5856
# Epoch 49/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.5786
# Epoch 50/100
# 5/5 [==============================] - 0s 915us/step - loss: 1.5725
# Epoch 51/100
# 5/5 [==============================] - 0s 718us/step - loss: 1.5698
# Epoch 52/100
# 5/5 [==============================] - 0s 815us/step - loss: 1.5660
# Epoch 53/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.5635
# Epoch 54/100
# 5/5 [==============================] - 0s 993us/step - loss: 1.5613
# Epoch 55/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5596
# Epoch 56/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5572
# Epoch 57/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5547
# Epoch 58/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.5517
# Epoch 59/100
# 5/5 [==============================] - 0s 912us/step - loss: 1.5498
# Epoch 60/100
# 5/5 [==============================] - 0s 793us/step - loss: 1.5475
# Epoch 61/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5450
# Epoch 62/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5429
# Epoch 63/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5407
# Epoch 64/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.5384
# Epoch 65/100
# 5/5 [==============================] - 0s 788us/step - loss: 1.5367
# Epoch 66/100
# 5/5 [==============================] - 0s 829us/step - loss: 1.5327
# Epoch 67/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.5305
# Epoch 68/100
# 5/5 [==============================] - 0s 841us/step - loss: 1.5317
# Epoch 69/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.5276
# Epoch 70/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.5232
# Epoch 71/100
# 5/5 [==============================] - 0s 805us/step - loss: 1.5217
# Epoch 72/100
# 5/5 [==============================] - 0s 808us/step - loss: 1.5190
# Epoch 73/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.5170
# Epoch 74/100
# 5/5 [==============================] - 0s 803us/step - loss: 1.5142
# Epoch 75/100
# 5/5 [==============================] - 0s 808us/step - loss: 1.5117
# Epoch 76/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.5096
# Epoch 77/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.5069
# Epoch 78/100
# 5/5 [==============================] - 0s 984us/step - loss: 1.5048
# Epoch 79/100
# 5/5 [==============================] - 0s 919us/step - loss: 1.5017
# Epoch 80/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.4995
# Epoch 81/100
# 5/5 [==============================] - 0s 793us/step - loss: 1.4973
# Epoch 82/100
# 5/5 [==============================] - 0s 753us/step - loss: 1.4948
# Epoch 83/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.4922
# Epoch 84/100
# 5/5 [==============================] - 0s 763us/step - loss: 1.4911
# Epoch 85/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.4881
# Epoch 86/100
# 5/5 [==============================] - 0s 961us/step - loss: 1.4845
# Epoch 87/100
# 5/5 [==============================] - 0s 805us/step - loss: 1.4819
# Epoch 88/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.4799
# Epoch 89/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.4777
# Epoch 90/100
# 5/5 [==============================] - 0s 987us/step - loss: 1.4753
# Epoch 91/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.4741
# Epoch 92/100
# 5/5 [==============================] - 0s 791us/step - loss: 1.4704
# Epoch 93/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.4673
# Epoch 94/100
# 5/5 [==============================] - 0s 782us/step - loss: 1.4651
# Epoch 95/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.4626
# Epoch 96/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.4604
# Epoch 97/100
# 5/5 [==============================] - 0s 806us/step - loss: 1.4581
# Epoch 98/100
# 5/5 [==============================] - 0s 598us/step - loss: 1.4556
# Epoch 99/100
# 5/5 [==============================] - 0s 733us/step - loss: 1.4534
# Epoch 100/100
# 5/5 [==============================] - 0s 809us/step - loss: 1.4507

# %%
y_train_pred = nn_model.predict(X_train_scaled)
y_test_pred = nn_model.predict(X_test_scaled)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.7584599704774504

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.656092599635322

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()

# %%
deep_model = tf.keras.models.Sequential()

# %%
deep_model.add(tf.keras.layers.Dense(units=len(X.columns) *2, activation = 'relu', input_dim = len(X.columns)))

# %%
deep_model.add(tf.keras.layers.Dense(units=len(X.columns) *2, activation = 'relu'))

# %%
deep_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
deep_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 24)                312
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 25
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 939
# Trainable params: 939
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(loss="mean_squared_error", optimizer="adam")

# %%
deep_model.fit(X_train_scaled, np.asarray(y_train), epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 798us/step - loss: 44.7699
# Epoch 2/100
# 5/5 [==============================] - 0s 798us/step - loss: 42.1826
# Epoch 3/100
# 5/5 [==============================] - 0s 997us/step - loss: 39.6352
# Epoch 4/100
# 5/5 [==============================] - 0s 598us/step - loss: 36.9898
# Epoch 5/100
# 5/5 [==============================] - 0s 912us/step - loss: 34.2055
# Epoch 6/100
# 5/5 [==============================] - 0s 791us/step - loss: 31.1780
# Epoch 7/100
# 5/5 [==============================] - 0s 788us/step - loss: 28.0728
# Epoch 8/100
# 5/5 [==============================] - 0s 571us/step - loss: 24.8270
# Epoch 9/100
# 5/5 [==============================] - 0s 798us/step - loss: 21.4705
# Epoch 10/100
# 5/5 [==============================] - 0s 798us/step - loss: 18.2106
# Epoch 11/100
# 5/5 [==============================] - 0s 946us/step - loss: 14.8769
# Epoch 12/100
# 5/5 [==============================] - 0s 798us/step - loss: 11.7264
# Epoch 13/100
# 5/5 [==============================] - 0s 792us/step - loss: 8.9239
# Epoch 14/100
# 5/5 [==============================] - 0s 798us/step - loss: 6.4803
# Epoch 15/100
# 5/5 [==============================] - 0s 798us/step - loss: 4.5988
# Epoch 16/100
# 5/5 [==============================] - 0s 798us/step - loss: 3.3136
# Epoch 17/100
# 5/5 [==============================] - 0s 805us/step - loss: 2.5863
# Epoch 18/100
# 5/5 [==============================] - 0s 598us/step - loss: 2.2678
# Epoch 19/100
# 5/5 [==============================] - 0s 859us/step - loss: 2.2456
# Epoch 20/100
# 5/5 [==============================] - 0s 592us/step - loss: 2.2504
# Epoch 21/100
# 5/5 [==============================] - 0s 997us/step - loss: 2.2618
# Epoch 22/100
# 5/5 [==============================] - 0s 775us/step - loss: 2.2385
# Epoch 23/100
# 5/5 [==============================] - 0s 752us/step - loss: 2.1883
# Epoch 24/100
# 5/5 [==============================] - 0s 791us/step - loss: 2.1696
# Epoch 25/100
# 5/5 [==============================] - 0s 869us/step - loss: 2.1508
# Epoch 26/100
# 5/5 [==============================] - 0s 1ms/step - loss: 2.1468
# Epoch 27/100
# 5/5 [==============================] - 0s 805us/step - loss: 2.1347
# Epoch 28/100
# 5/5 [==============================] - 0s 798us/step - loss: 2.1163
# Epoch 29/100
# 5/5 [==============================] - 0s 1ms/step - loss: 2.1076
# Epoch 30/100
# 5/5 [==============================] - 0s 798us/step - loss: 2.0893
# Epoch 31/100
# 5/5 [==============================] - 0s 965us/step - loss: 2.0764
# Epoch 32/100
# 5/5 [==============================] - 0s 599us/step - loss: 2.0627
# Epoch 33/100
# 5/5 [==============================] - 0s 997us/step - loss: 2.0487
# Epoch 34/100
# 5/5 [==============================] - 0s 798us/step - loss: 2.0369
# Epoch 35/100
# 5/5 [==============================] - 0s 798us/step - loss: 2.0243
# Epoch 36/100
# 5/5 [==============================] - 0s 1ms/step - loss: 2.0086
# Epoch 37/100
# 5/5 [==============================] - 0s 916us/step - loss: 2.0018
# Epoch 38/100
# 5/5 [==============================] - 0s 805us/step - loss: 1.9886
# Epoch 39/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.9747
# Epoch 40/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.9612
# Epoch 41/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.9516
# Epoch 42/100
# 5/5 [==============================] - 0s 994us/step - loss: 1.9490
# Epoch 43/100
# 5/5 [==============================] - 0s 796us/step - loss: 1.9341
# Epoch 44/100
# 5/5 [==============================] - 0s 988us/step - loss: 1.9128
# Epoch 45/100
# 5/5 [==============================] - 0s 816us/step - loss: 1.8970
# Epoch 46/100
# 5/5 [==============================] - 0s 987us/step - loss: 1.8868
# Epoch 47/100
# 5/5 [==============================] - 0s 797us/step - loss: 1.8706
# Epoch 48/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.8558
# Epoch 49/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.8396
# Epoch 50/100
# 5/5 [==============================] - 0s 599us/step - loss: 1.8241
# Epoch 51/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.8111
# Epoch 52/100
# 5/5 [==============================] - 0s 806us/step - loss: 1.7939
# Epoch 53/100
# 5/5 [==============================] - 0s 812us/step - loss: 1.7790
# Epoch 54/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.7576
# Epoch 55/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.7359
# Epoch 56/100
# 5/5 [==============================] - 0s 820us/step - loss: 1.7208
# Epoch 57/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.7003
# Epoch 58/100
# 5/5 [==============================] - 0s 690us/step - loss: 1.6763
# Epoch 59/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.6451
# Epoch 60/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.6195
# Epoch 61/100
# 5/5 [==============================] - 0s 2ms/step - loss: 1.5937
# Epoch 62/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.5696
# Epoch 63/100
# 5/5 [==============================] - 0s 781us/step - loss: 1.5474
# Epoch 64/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.5257
# Epoch 65/100
# 5/5 [==============================] - 0s 918us/step - loss: 1.5096
# Epoch 66/100
# 5/5 [==============================] - 0s 991us/step - loss: 1.4892
# Epoch 67/100
# 5/5 [==============================] - 0s 957us/step - loss: 1.4666
# Epoch 68/100
# 5/5 [==============================] - ETA: 0s - loss: 1.299 - 0s 1ms/step - loss: 1.4422
# Epoch 69/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.4244
# Epoch 70/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.3994
# Epoch 71/100
# 5/5 [==============================] - 0s 991us/step - loss: 1.3832
# Epoch 72/100
# 5/5 [==============================] - 0s 915us/step - loss: 1.3600
# Epoch 73/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.3562
# Epoch 74/100
# 5/5 [==============================] - 0s 804us/step - loss: 1.3197
# Epoch 75/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.3043
# Epoch 76/100
# 5/5 [==============================] - 0s 987us/step - loss: 1.2845
# Epoch 77/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.2598
# Epoch 78/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.2437
# Epoch 79/100
# 5/5 [==============================] - 0s 602us/step - loss: 1.2407
# Epoch 80/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.2158
# Epoch 81/100
# 5/5 [==============================] - 0s 992us/step - loss: 1.2030
# Epoch 82/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.1892
# Epoch 83/100
# 5/5 [==============================] - 0s 760us/step - loss: 1.1880
# Epoch 84/100
# 5/5 [==============================] - 0s 797us/step - loss: 1.1781
# Epoch 85/100
# 5/5 [==============================] - 0s 811us/step - loss: 1.1610
# Epoch 86/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.1463
# Epoch 87/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.1401
# Epoch 88/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.1250
# Epoch 89/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.1257
# Epoch 90/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.1066
# Epoch 91/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.1078
# Epoch 92/100
# 5/5 [==============================] - 0s 998us/step - loss: 1.0991
# Epoch 93/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.1057
# Epoch 94/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.1028
# Epoch 95/100
# 5/5 [==============================] - 0s 997us/step - loss: 1.0809
# Epoch 96/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0747
# Epoch 97/100
# 5/5 [==============================] - 0s 798us/step - loss: 1.0724
# Epoch 98/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0644
# Epoch 99/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0625
# Epoch 100/100
# 5/5 [==============================] - 0s 993us/step - loss: 1.0593

# %%
y_train_pred = deep_model.predict(X_train_scaled)
y_test_pred = deep_model.predict(X_test_scaled)

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.8240912929341712

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.730413700578764

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train_scaled, y_train)
# Out:
# 0.8665000965222467

# %%
model.score(X_test_scaled, y_test)
# Out:
# 0.7087415790368

# %%
# Regression relationship with Cohesion data
plt.scatter(y_test, y_test_pred, marker='o', c='blue')
plt.scatter(y_train, y_train_pred, marker='^', c='black')
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_test, m*y_test + b)
#a, b, c = np.polyfit(y_test, y_test_pred, 2)
#plt.plot(y_test, a*y_test*y_test+b*y_test+c)
# Show the boundary between the regions:
plt.show()
